# %%
#Q6
#Expected value
import numpy as np
candiescount = np.array([1,4,3,5,6,2])
prob= np.array([0.015,0.2,0.65,0.005,0.01,0.120])

def expected_value(candiescount, prob):
    return (candiescount * prob).sum()/prob.sum()
expected_value(candiescount, prob)

#==========================================
# Out:
# 3.09

# %%
# Q7) Calculate Mean, Median, Mode, Variance, Standard Deviation, Range &     comment about the values / draw inferences, for the given dataset
        ###-For Points,Score,Weigh>
        ###Find Mean, Median, Mode, Variance, Standard Deviation, and Range and also Comment about the values/ Draw some inferences.

import pandas as pd
df = pd.read_csv("C:/Users/DELL/Downloads/Q7.csv")
df
df.dtypes
print("mean of points:",df['Points'].mean())
print("median of points:",df['Points'].median())
print("variance of points:",df['Points'].var())
print("standard deviation of points:",df['Points'].std())
print("mode of points:",df['Points'].mode())
maxp=df['Points'].max()
minp=df['Points'].min()
print("range of Points [",minp,maxp,"]")
df['Points'].describe()
print("mean of score:",df['Score'].mean())
print("median of score:",df['Score'].median())
print("variance of score:",df['Score'].var())
print("standard deviation of score:",df['Score'].std())
print("mode of score:",df['Score'].mode())
maxs=df['Score'].max()
mins=df['Score'].min()
print("range of Score [",mins,maxs,"]")
df['Score'].describe()
print("mean of weigh:",df['Weigh'].mean())
print("median of weigh:",df['Weigh'].median())
print("variance of weigh:",df['Weigh'].var())
print("stadard deviation of weigh:",df['Weigh'].std())
print("mode of weigh:",df['Weigh'].mode())
maxw=df['Weigh'].max()
minw=df['Weigh'].min()
print("range of Weigh [",minw,maxw,"]")
df['Weigh'].describe()
df["Points"].plot(kind='bar')
df["Score"].plot(kind='bar')
df["Weigh"].plot(kind='bar')
df.boxplot(column=["Points"],vert=False)
df.boxplot(column=["Score"],vert=False)
df.boxplot(column=["Weigh"],vert=False)

#============================================================>

# Q8) Calculate Expected Value for the problem below
    ## a)The weights (X) of patients at a clinic (in pounds), are
    ## 108, 110, 123, 134, 135, 145, 167, 187, 199
    ## Assume one of the patients is chosen at random. What is the Expected Value of the Weight of that patient?
import numpy as np
weight=np.array([108, 110, 123, 134, 135, 145, 167, 187, 199])
weight.mean()
#============================================================>

# Q9) Calculate Skewness, Kurtosis & draw inferences on the following data
    ## Cars speed and distance 
          ## Use Q9_a.csv

    ##SP and Weight(WT)
        ##Use Q9_b.csv
import pandas as pd
from scipy.stats import skew,kurtosis
df_a=pd.read_csv("C:/Users/DELL/Downloads/Q9_a.csv")
df_a
df_a['speed'].hist()
df_a['speed'].skew()
df_a['speed'].kurtosis()
df_a['dist'].hist()
df_a['dist'].skew()
df_a['dist'].kurtosis()

df_b=pd.read_csv("C:/Users/DELL/Downloads/Q9_b.csv")
df_b
df_b["SP"].hist()
df_b['SP'].skew()
df_b['SP'].kurtosis()
df_b["WT"].hist()
df_b['WT'].skew()
df_b['WT'].kurtosis()
skewness = skew(df_a,bias= True)
skewness
kurtosis = kurtosis(df_b,bias= True)
kurtosis
#============================================================>
# Q11)  Suppose we want to estimate the average weight of an adult male in    Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weigh them. We find that the average person in our sample weighs 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?
avg_w=200
std_m=30
from scipy.stats import norm
df_ci=norm.interval(0.94,avg_w,std_m)
#alpha 6%
print("i am 94% confident that population mean is lies under:",df_ci)
df_ci=norm.interval(0.96,avg_w,std_m)
#alpha 4%
print("i am 96% confident that population mean is lies under:",df_ci)
df_ci=norm.interval(0.98,avg_w,std_m)
#alpha 6%
print("i am 98% confident that population mean is lies under:",df_ci)
#============================================================>
# Q12)  Below are the scores obtained by a student in tests 
    ## 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56
    ## 1) Find mean, median, variance, standard deviation.
    ## 2) What can we say about the student marks?
df=pd.read_csv("D:/Assignments/assignment/SCORES.csv")
df

print("mean:",df.mean())
print("standard deviation:",df.std())
print("median:",df.median())
print("variance:",df.var())

df.hist()
## student Marks are Possitively skewed
#============================================================>
# Q 20 & 21a) Calculate probability from the given dataset for the below cases

    ## Data _set: Cars.csv
    ## Calculate the probability of MPG  of Cars for the below cases.
    ## MPG <- Cars$MPG
    ## a.P(MPG>38)
    ## b.P(MPG<40)
    ## c.P(20<MPG<50 
df=pd.read_csv("C:/Users/DELL/Downloads/Cars.csv")
df
#H0: Data is normal
#H1:Data is not normal

from scipy.stats import shapiro
test,pvalue=shapiro(df['MPG'])
pvalue
alpha=0.05
if pvalue<alpha:
    print("H0 is rejected and H1 is accepted")
else:
    print("H0 is accepted and H1 is rejected")
mean_mpg=df['MPG'].mean()
std_mpg=df['MPG'].std()
#NORMAL DISTRIBUTION
from scipy.stats import norm

nd=norm(mean_mpg,std_mpg)#mean,sd
#P(MPG<38)
nd.cdf(38)
#p(MPG>38)
1-nd.cdf(38)
#P(MPG<40)
nd.cdf(40)
#P(20<MPG<50)
nd.cdf(50)-nd.cdf(20)
#============================
#21b)Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution 
       ## Dataset: wc-at.csv
df=pd.read_csv("C:/Users/DELL/Downloads/wc-at.csv")
df
#H0: Data is normal
#H1:Data is not normal

from scipy.stats import shapiro
test,pvalue=shapiro(df["Waist"])
pvalue
alpha=0.05
if pvalue<alpha:
    print("H0 is rejected and H1 is accepted")
else:
    print("H0 is accepted and H1 is rejected")
from scipy.stats import shapiro
test,pvalue=shapiro(df["AT"])
pvalue
alpha=0.05
if pvalue<alpha:
    print("H0 is rejected and H1 is accepted")
else:
    print("H0 is accepted and H1 is rejected")
#============================================================>
# Q 22) Calculate the Z scores of  90% confidence interval,94% confidence interval, 60% confidence interval 

import scipy.stats as stats
#90% confidence
Z_Score = stats.norm.ppf((1+0.90)/2)
Z_Score
#94% confidence
Z_Score = stats.norm.ppf((1+0.94)/2)
Z_Score
#60% confidence
Z_Score = stats.norm.ppf((1+0.60)/2)
Z_Score


#============================================================>

# Q 23) Calculate the t scores of 95% confidence interval, 96% confidence interval, 99% confidence interval for sample size of 25
Sample_size = 25

import scipy.stats as stats

Degree_of_freedom = Sample_size - 1
#95% confidence
T_Score = stats.t.ppf((1+0.95)/2,Degree_of_freedom)
T_Score
#96% confidence
T_Score = stats.t.ppf((1+0.96)/2,Degree_of_freedom)
T_Score
#99% confidence
T_Score = stats.t.ppf((1+0.99)/2,Degree_of_freedom)
T_Score



 #============================================================>
# Q 24)   A Government  company claims that an average light bulb lasts 270 days. A researcher randomly selects 18 bulbs for testing. The sampled bulbs last an average of 260 days, with a standard deviation of 90 days. If the CEO's claim were true, what is the probability that 18 randomly selected bulbs would have an average life of no more than 260 days
# Hint:  rcode   pt(tscore,df)   df  degrees of freedom

## Given Data 
Population_mean_Days = 270
Sample_size = 18
Sample_mean_Days = 260
Standard_deviation_Days = 90
    ## Probability of n <= 260 Days

T_Score = (Sample_mean_Days-Population_mean_Days)/(Standard_deviation_Days/(Sample_size**0.5))
T_Score

Degree_of_freedom = Sample_size - 1
Degree_of_freedom

import scipy.stats as stats

P_Value = stats.t.cdf(T_Score,Degree_of_freedom)
P_Value
print("The probability that 18 randomly selected bulbs would have an average life of no more than 260 days is ", (P_Value*100).round(2),"%")
# Out:
# mean of points: 3.5965625
# median of points: 3.6950000000000003
# variance of points: 0.28588135080645166
# standard deviation of points: 0.5346787360709716
# mode of points: 0    3.07
# 1    3.92
# Name: Points, dtype: float64
# range of Points [ 2.76 4.93 ]
# mean of score: 3.2172500000000004
# median of score: 3.325
# variance of score: 0.9573789677419356
# standard deviation of score: 0.9784574429896967
# mode of score: 0    3.44
# Name: Score, dtype: float64
# range of Score [ 1.513 5.424 ]
# mean of weigh: 17.848750000000003
# median of weigh: 17.71
# variance of weigh: 3.193166129032258
# stadard deviation of weigh: 1.7869432360968431
# mode of weigh: 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64
# range of Weigh [ 14.5 22.9 ]
# i am 94% confident that population mean is lies under: (143.57619175546247, 256.42380824453755)
# i am 96% confident that population mean is lies under: (138.38753268104531, 261.61246731895466)
# ...
